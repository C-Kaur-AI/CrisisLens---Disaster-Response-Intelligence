# %% [markdown]
# # CrisisLens — EDA & Zero-Shot Baseline
#
# This notebook provides:
# - Dataset exploration (HumAID/CrisisBench)
# - Class distribution and language distribution
# - Zero-shot baseline vs fine-tuned comparison (add your results)
# - Confusion matrix visualization

# %%
import sys
sys.path.insert(0, '..')

import pandas as pd
from pathlib import Path

# %% [markdown]
# ## 1. Load Data

# %%
# Load sample messages or HumAID if available
data_path = Path('../data/samples/sample_messages.json')
if data_path.exists():
    df = pd.read_json(data_path)
else:
    df = pd.DataFrame()

print(f'Loaded {len(df)} samples')
df.head()

# %% [markdown]
# ## 2. Class Distribution

# %%
if 'type' in df.columns:
    df['type'].value_counts().plot(kind='bar', figsize=(10, 4))
    plt.title('Event Type Distribution')
    plt.tight_layout()

# %% [markdown]
# ## 3. Run Evaluation

# %%
# Run: python evaluate.py --data ../data/samples/sample_messages.json
# Then load and visualize results

# %%
# Placeholder for confusion matrix
# from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
# cm = confusion_matrix(y_true, y_pred)
# disp = ConfusionMatrixDisplay(confusion_matrix=cm)
# disp.plot()
